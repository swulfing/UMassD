# %%
# %pip install copernicusmarine
#%pip install "setuptools<66"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import copernicusmarine

# %%
# ?copernicusmarine.subset
# Out:
# Signature:
# copernicusmarine.subset(
#     dataset_id: str | None = None,
#     dataset_version: str | None = None,
#     dataset_part: str | None = None,
#     username: str | None = None,
#     password: str | None = None,
#     variables: list[str] | None = None,
#     minimum_longitude: float | None = None,
#     maximum_longitude: float | None = None,
#     minimum_latitude: float | None = None,
#     maximum_latitude: float | None = None,
#     minimum_depth: float | None = None,
#     maximum_depth: float | None = None,
#     vertical_axis: Literal['depth', 'elevation'] = 'depth',
#     start_datetime: datetime.datetime | pandas._libs.tslibs.timestamps.Timestamp | str | None = None,
#     end_datetime: datetime.datetime | pandas._libs.tslibs.timestamps.Timestamp | str | None = None,
#     minimum_x: float | None = None,
#     maximum_x: float | None = None,
#     minimum_y: float | None = None,
#     maximum_y: float | None = None,
# ...

# %%
#import copernicusmarine

copernicusmarine.subset(
  dataset_id="cmems_mod_glo_phy_anfc_0.083deg_P1D-m",
  variables=["usi"],
  minimum_longitude=-74.97460894949772,
  maximum_longitude=-38.01036430664059,
  minimum_latitude=5.869831647600446,
  maximum_latitude=27.164450844029012,
  start_datetime="2024-08-21T00:00:00",
  end_datetime="2024-08-23T00:00:00",
  minimum_depth=0.49402499198913574,
  maximum_depth=20,
)
# Out:
# INFO - 2026-04-21T20:31:12Z - Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# Copernicus Marine username:
#   swulfing
# Copernicus Marine password:
#   ········
# INFO - 2026-04-21T20:32:06Z - Selected dataset version: "202406"
# INFO - 2026-04-21T20:32:06Z - Selected dataset part: "default"
# ---------------------------------------------------------------------------
# InvalidVersion                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 #import copernicusmarine
# ----> 3 copernicusmarine.subset(
#       4   dataset_id="cmems_mod_glo_phy_anfc_0.083deg_P1D-m",
#       5   variables=["usi"],
#       6   minimum_longitude=-74.97460894949772,
#       7   maximum_longitude=-38.01036430664059,
#       8   minimum_latitude=5.869831647600446,
#       9   maximum_latitude=27.164450844029012,
#      10   start_datetime="2024-08-21T00:00:00",
# ...
